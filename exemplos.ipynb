# %%
from transformers import pipeline

emotion = pipeline('sentiment-analysis', model='arpanghoshal/EmoRoBERTa')

# diferenciação entre o uso de apostrofo ou não

# text = "He isnt feeling very well"
#text = "He isn't feeling very well"
text = "Im not feeling very well"

emotion_labels = emotion(text)
print(emotion_labels)
# Out:
# 2023-02-27 21:05:40.429391: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-27 21:05:40.734581: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-02-27 21:05:40.734595: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# ...

# %% [markdown]
# ## EmoRoBERTa

# %%
# text = "im alone i feel awful"
text = "i was feeling a little low few days back"

emoroberta = pipeline('sentiment-analysis', model='arpanghoshal/EmoRoBERTa')
print(f'EmoRoberta: {emotion(text)}')

emotion_classifier = pipeline("sentiment-analysis", model="michellejieli/emotion_text_classifier")
print(f'EmotionClassifier: {emotion_classifier(text)}')


distilbert_uncased = pipeline("text-classification", model="bhadresh-savani/distilbert-base-uncased-emotion")
print(f'distilbert_uncased: {distilbert_uncased(text)}')

bert_based = pipeline("text-classification", model="bhadresh-savani/bert-base-uncased-emotion")
print(f'bert_based: {bert_based(text)}')

emotion_english = pipeline("text-classification", model="j-hartmann/emotion-english-distilroberta-base")
print(f'emotion_english: {emotion_english(text)}')
# Out:
# All model checkpoint layers were used when initializing TFRobertaForSequenceClassification.
#
# All the layers of TFRobertaForSequenceClassification were initialized from the model checkpoint at arpanghoshal/EmoRoBERTa.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaForSequenceClassification for predictions without further training.
# EmoRoberta: [{'label': 'realization', 'score': 0.5083200335502625}]
# EmotionClassifier: [{'label': 'sadness', 'score': 0.834538996219635}]
# distilbert_uncased: [{'label': 'sadness', 'score': 0.9988862872123718}]
# bert_based: [{'label': 'sadness', 'score': 0.9986518025398254}]
# emotion_english: [{'label': 'sadness', 'score': 0.9930734038352966}]

# %%
import pickle
def load_from_pickle(directory):
    return pickle.load(open(directory,"rb"))

# Loading the data
data = load_from_pickle(directory="merged_training.pkl")
sliced_data = data[:20]

sliced_data
# Out:
#                                                      text emotions
# 27383   i feel awful about it too because it s my job ...  sadness
# 110083                              im alone i feel awful  sadness
# 140764  ive probably mentioned this before but i reall...      joy
# 100071           i was feeling a little low few days back  sadness
# 2837    i beleive that i am much more sensitive to oth...     love
# 18231   i find myself frustrated with christians becau...     love
# 10714   i am one of those people who feels like going ...      joy
# 35177   i feel especially pleased about this as this h...      joy
# 122177  i was struggling with these awful feelings and...      joy
# 26723     i feel so enraged but helpless at the same time    anger
# 41979                     i said feeling a bit rebellious    anger
# 2046    i also feel disillusioned that someone who cla...  sadness
# 98659   i mean is on this stupid trip of making the gr...      joy
# ...

# %%
import pickle
import pandas as pd
def load_from_pickle(directory):
    return pickle.load(open(directory,"rb"))

# Loading the data
data = load_from_pickle(directory="merged_training.pkl")
sliced_data = data[:20]



emoroberta = pipeline('sentiment-analysis', model='arpanghoshal/EmoRoBERTa')
# print(f'EmoRoberta: {emotion(text)}')
# sliced_data.assign(emoroberta=lambda df : emotion(str(df.text)))
sliced_data['emoroberta'] = sliced_data['text'].apply(lambda x: emoroberta(x))


emotion_classifier = pipeline("sentiment-analysis", model="michellejieli/emotion_text_classifier")
# print(f'EmotionClassifier: {emotion_classifier(text)}')
sliced_data['emotion_classifier'] = sliced_data['text'].apply(lambda x: emotion_classifier(x))

distilbert_uncased = pipeline("text-classification", model="bhadresh-savani/distilbert-base-uncased-emotion")
# print(f'distilbert_uncased: {distilbert_uncased(text)}')
sliced_data['distilbert_uncased'] = sliced_data['text'].apply(lambda x: distilbert_uncased(x))

bert_based = pipeline("text-classification", model="bhadresh-savani/bert-base-uncased-emotion")
# print(f'bert_based: {bert_based(text)}')
sliced_data['bert_based'] = sliced_data['text'].apply(lambda x: bert_based(x))

emotion_english = pipeline("text-classification", model="j-hartmann/emotion-english-distilroberta-base")
# print(f'emotion_english: {emotion_english(text)}')
sliced_data['emotion_english'] = sliced_data['text'].apply(lambda x: emotion_english(x))

with pd.option_context('display.max_colwidth', None):
  display(sliced_data)
# Out:
# All model checkpoint layers were used when initializing TFRobertaForSequenceClassification.
#
# All the layers of TFRobertaForSequenceClassification were initialized from the model checkpoint at arpanghoshal/EmoRoBERTa.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaForSequenceClassification for predictions without further training.
# /tmp/ipykernel_12291/3228878854.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sliced_data['emoroberta'] = sliced_data['text'].apply(lambda x: emoroberta(x))
# /tmp/ipykernel_12291/3228878854.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
from transformers import pipeline
import pickle
import pandas as pd
def load_from_pickle(directory):
    return pickle.load(open(directory,"rb"))

# Loading the data
data = load_from_pickle(directory="merged_training.pkl")
data['text'] = data['text'].astype('str')
newdata = data.loc[data['text'].str.len()>500]


emoroberta = pipeline('sentiment-analysis', model='arpanghoshal/EmoRoBERTa')
# print(f'EmoRoberta: {emotion(text)}')
# sliced_data.assign(emoroberta=lambda df : emotion(str(df.text)))
newdata['emoroberta'] = newdata['text'].apply(lambda x: emoroberta(x))


emotion_classifier = pipeline("sentiment-analysis", model="michellejieli/emotion_text_classifier")
# print(f'EmotionClassifier: {emotion_classifier(text)}')
newdata['emotion_classifier'] = newdata['text'].apply(lambda x: emotion_classifier(x))

distilbert_uncased = pipeline("text-classification", model="bhadresh-savani/distilbert-base-uncased-emotion")
# print(f'distilbert_uncased: {distilbert_uncased(text)}')
newdata['distilbert_uncased'] = newdata['text'].apply(lambda x: distilbert_uncased(x))

bert_based = pipeline("text-classification", model="bhadresh-savani/bert-base-uncased-emotion")
# print(f'bert_based: {bert_based(text)}')
newdata['bert_based'] = newdata['text'].apply(lambda x: bert_based(x))

emotion_english = pipeline("text-classification", model="j-hartmann/emotion-english-distilroberta-base")
# print(f'emotion_english: {emotion_english(text)}')
newdata['emotion_english'] = newdata['text'].apply(lambda x: emotion_english(x))

with pd.option_context('display.max_colwidth', None):
  display(newdata)
# Out:
# 2023-02-28 16:23:28.749694: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-28 16:23:31.511891: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-02-28 16:23:31.511906: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# ...

# %%
from transformers import pipeline
import pickle
import pandas as pd
# def load_from_pickle(directory):
#     return pickle.load(open(directory,"rb"))

# # Loading the data
# data = load_from_pickle(directory="merged_training.pkl")
# data['text'] = data['text'].astype('str')
# newdata = data.loc[data['text'].str.len()>500]

# data = {'text':["I am overwhelmed with joy and gratitude as I stand here today, surrounded by my loved ones, celebrating this incredible milestone in my life. I cannot express how much this moment means to me - the memories we've made, the challenges we've overcome, and the endless support and encouragement we've received along the way. Every step of this journey has been a testament to the power of love, determination, and perseverance, and I am so blessed to have had each and every one of you by my side. From the bottom of my heart, thank you for making this day the happiest day of my life.","There is a fire burning within me, a fierce and unrelenting rage that threatens to consume me from the inside out. It is the anger of a thousand injustices, the fury of a million broken promises, and the frustration of a world that refuses to listen to the voices of the oppressed and marginalized. It is the pain of watching our planet being destroyed, our freedoms being taken away, and our humanity being stripped away by greed and corruption. And yet, despite it all, I refuse to let this anger defeat me. For I know that it is this very anger that will fuel my fight for justice, for equality, and for a better world.","There is a deep ache in my heart that refuses to go away, a sadness that lingers no matter how hard I try to shake it off. It is the feeling of losing something precious - a loved one, a dream, a part of myself - and the emptiness that remains in its absence. It is the heaviness that weighs me down, the tears that fall uncontrollably, and the sense of hopelessness that takes hold. And yet, even in the midst of this sadness, I find solace in knowing that I am not alone, that there are others who understand and who offer comfort and support. For it is in our shared humanity, in our capacity to feel and to connect, that we find the strength to endure.","Sadness is a complex and multifaceted emotion, one that can take many different forms and arise from many different sources. It is the feeling of nostalgia for a time gone by, the regret for choices not taken, and the uncertainty of an unknown future. It is the pain of unfulfilled expectations, the frustration of unmet needs, and the fear of rejection and abandonment. And yet, amidst all of this, there is also a sense of beauty and poignancy to sadness - a reminder of the fleeting nature of life, the importance of cherishing what we have, and the possibility of transformation and growth. So let us embrace our sadness, let us honor it and learn from it, and let us find hope and healing in the midst of our pain.","Anger is a force to be reckoned with - a primal, raw, and powerful emotion that can unleash both destruction and transformation. It is the feeling of betrayal when someone you trusted lets you down, the frustration of being misunderstood and dismissed, and the indignation of witnessing injustice and cruelty. It is the impulse to lash out, to fight back, and to demand change. And while it may be uncomfortable, even terrifying, to confront this anger head-on, it is also necessary if we are to channel it into constructive action. So let us not shy away from our anger, let us not suppress it or deny it, but let us harness it to create a better world.","Anger is a force to be reckoned with - a primal, raw, and powerful emotion that can unleash both destruction and transformation. It is the feeling of betrayal when someone you trusted lets you down, the frustration of being misunderstood and dismissed, and the indignation of witnessing injustice and cruelty. It is the impulse to lash out, to fight back, and to demand change. And while it may be uncomfortable, even terrifying, to confront this anger head-on, it is also necessary if we are to channel it into constructive action. So let us not shy away from our anger, let us not suppress it or deny it, but let us harness it to create a better world."
                # ],'emotion':['joy','anger','sadness','sadness','anger','joy']}

# df = pd.DataFrame(data=data)
df = pd.read_csv('dados.csv')
emoroberta = pipeline('sentiment-analysis', model='arpanghoshal/EmoRoBERTa')
# print(f'EmoRoberta: {emotion(text)}')
# sliced_data.assign(emoroberta=lambda df : emotion(str(df.text)))
df['emoroberta'] = df['text'].apply(lambda x: emoroberta(x))


emotion_classifier = pipeline("sentiment-analysis", model="michellejieli/emotion_text_classifier")
# print(f'EmotionClassifier: {emotion_classifier(text)}')
df['emotion_classifier'] = df['text'].apply(lambda x: emotion_classifier(x))

distilbert_uncased = pipeline("text-classification", model="bhadresh-savani/distilbert-base-uncased-emotion")
# print(f'distilbert_uncased: {distilbert_uncased(text)}')
df['distilbert_uncased'] = df['text'].apply(lambda x: distilbert_uncased(x))

bert_based = pipeline("text-classification", model="bhadresh-savani/bert-base-uncased-emotion")
# print(f'bert_based: {bert_based(text)}')
df['bert_based'] = df['text'].apply(lambda x: bert_based(x))

emotion_english = pipeline("text-classification", model="j-hartmann/emotion-english-distilroberta-base")
# print(f'emotion_english: {emotion_english(text)}')
df['emotion_english'] = df['text'].apply(lambda x: emotion_english(x))

with pd.option_context('display.max_colwidth', None):
  display(df)
# Out:
# 2023-02-28 21:53:35.870772: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-02-28 21:53:35.876598: W tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-02-28 21:53:35.876631: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (felipe-desktop): /proc/driver/nvidia/version does not exist
# 2023-02-28 21:53:35.895285: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
